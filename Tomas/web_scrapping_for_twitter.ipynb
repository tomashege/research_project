# %% [markdown]
# # web scrapping for twitter handels

# %%
from selenium import webdriver
import pandas as pd
import time

# %%
driver = webdriver.Chrome('/Users/tomashegewisch/Downloads/chromedriver')

# %%
driver.get('https://twitter.com/search?q=%23COVIDIOTS&src=trend_click')

# %%
a = [];
handels = []
c = 10;
for i in range(0, 10000):
    #try:
    a = driver.find_elements_by_class_name("r-1f6r7vd");
    for i in a:
        try:
            handels.append(i.text)
        except:
            #print("1")
            print()
        #print(i.text)
    c += 200
    driver.execute_script("window.scrollTo(0, "+str(c)+");")
    time.sleep(2)
    #except:
    #    print("Error")
print(handels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-701274f477cd> in <module>
#      14     c += 200
#      15     driver.execute_script("window.scrollTo(0, "+str(c)+");")
# ---> 16     time.sleep(2)
#      17     #except:
#      18     #    print("Error")
#
# KeyboardInterrupt:

# %%
for i in handels:
    print(i)
# Out:
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @skiologist
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @skiologist
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @skiologist
# @hugookpala
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @skiologist
# @OderinwaleOpey1
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# @skiologist
# @OderinwaleOpey1
# @ogechikero
# @SwaeAy
# @LMMinichiello
# @stevesurrey1
# @infokianiaaron
# ...
